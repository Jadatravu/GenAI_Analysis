# %%
import os
import glob
from typing import List, Dict, Any, Set

from dotenv import load_dotenv

#from langchain.globals import set_llm_cache
#from langchain.cache import set_llm_cache

import langchain
from langchain_redis import RedisCache
import time



from langchain_core.documents import Document
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.runnables import RunnablePassthrough, RunnableLambda

from langchain_openai import ChatOpenAI, OpenAIEmbeddings
from langchain_text_splitters import RecursiveCharacterTextSplitter

from langchain_redis import RedisCache, RedisVectorStore, RedisConfig

# PDF loaders
from langchain_community.document_loaders import PyPDFLoader
import pandas as pd
import numpy as np

# ----------------------------
# Load .env first
# ----------------------------
load_dotenv()  # loads .env from current working dir (or nearest parent)


# ----------------------------
# Config (from env)
# ----------------------------
REDIS_URL = os.getenv("REDIS_URL", "redis://10.103.6.142:6379")
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")

DATA_DIR = os.getenv("DATA_DIR", "./data")
INDEX_NAME = os.getenv("REDIS_INDEX_NAME", "rag_pdfs")
CACHE_TTL_SECONDS = int(os.getenv("REDIS_CACHE_TTL_SECONDS", "3600"))

EMBEDDING_MODEL = os.getenv("EMBEDDING_MODEL", "text-embedding-3-large")
CHAT_MODEL = os.getenv("CHAT_MODEL", "gpt-4o-mini")

CHUNK_SIZE = int(os.getenv("CHUNK_SIZE", "900"))
CHUNK_OVERLAP = int(os.getenv("CHUNK_OVERLAP", "150"))

TOP_K = int(os.getenv("TOP_K", "4"))
EVAL_CSV_PATH = os.getenv("EVAL_CSV_PATH", "./eval_dataset.csv")
EVAL_OUT_CSV_PATH = os.getenv("EVAL_OUT_CSV_PATH", "./eval_results.csv")
EVAL_QUESTION_COL = os.getenv("EVAL_QUESTION_COL", "question")
EVAL_REFERENCE_COL = os.getenv("EVAL_REFERENCE_COL", "reference_answer")
EVAL_MAX_ROWS = int(os.getenv("EVAL_MAX_ROWS", "0"))  # 0 => all rows

langchain.llm_cache = RedisCache(
    redis_url=REDIS_URL,
    ttl=CACHE_TTL_SECONDS
)
# ----------------------------
# Utilities
# ----------------------------
def ensure_env():
    if not OPENAI_API_KEY:
        raise RuntimeError("Missing OPENAI_API_KEY (set it in .env).")
    if not REDIS_URL:
        raise RuntimeError("Missing REDIS_URL (set it in .env).")


def find_pdfs(data_dir: str) -> List[str]:
    pattern = os.path.join(data_dir, "**", "*.pdf")
    return sorted(glob.glob(pattern, recursive=True))

def cosine_sim(vec_a: List[float], vec_b: List[float]) -> float:
    a = np.array(vec_a, dtype=np.float32)
    b = np.array(vec_b, dtype=np.float32)
    denom = (np.linalg.norm(a) * np.linalg.norm(b))
    if denom == 0:
        return 0.0
    return float(np.dot(a, b) / denom)


def safe_text(x: Any) -> str:
    if x is None:
        return ""
    if isinstance(x, float) and np.isnan(x):
        return ""
    return str(x).strip()

def load_pdf_docs(pdf_paths: List[str], base_dir: str) -> List[Document]:
    """
    Loads PDFs into Documents.
    Each page becomes a Document; we add metadata: source (relative path) + page.
    """
    docs: List[Document] = []
    for path in pdf_paths:
        loader = PyPDFLoader(path)
        loaded = loader.load()  # one doc per page, includes metadata like 'page'
        rel = os.path.relpath(path, base_dir)

        for d in loaded:
            # Normalize metadata for consistent source reporting
            d.metadata = d.metadata or {}
            d.metadata["source"] = rel
            # keep page if present; PyPDFLoader typically includes 'page'
            docs.append(d)

    return docs


def chunk_docs(docs: List[Document]) -> List[Document]:
    splitter = RecursiveCharacterTextSplitter(
        chunk_size=CHUNK_SIZE,
        chunk_overlap=CHUNK_OVERLAP,
    )
    return splitter.split_documents(docs)


def format_docs_with_sources(docs: List[Document]) -> str:
    """
    Formats retrieved docs into a context string.
    """
    out = []
    for i, d in enumerate(docs, start=1):
        src = d.metadata.get("source", "unknown")
        page = d.metadata.get("page", None)
        page_str = f", page {page}" if page is not None else ""
        out.append(f"---\nChunk {i} [source: {src}{page_str}]\n{d.page_content}")
    return "\n".join(out)


def extract_sources(docs: List[Document]) -> List[str]:
    """
    Builds a stable list of sources used.
    Includes page numbers when available.
    """
    s: Set[str] = set()
    for d in docs:
        src = d.metadata.get("source", "unknown")
        page = d.metadata.get("page", None)
        if page is not None:
            s.add(f"{src} (page {page})")
        else:
            s.add(src)
    return sorted(s)


# ----------------------------
# Redis Vector Store + Cache
# ----------------------------
def build_vector_store() -> RedisVectorStore:
    embeddings = OpenAIEmbeddings(model=EMBEDDING_MODEL)
    config = RedisConfig(
        index_name=INDEX_NAME,
        redis_url=REDIS_URL,
        distance_metric="COSINE",
    )
    return RedisVectorStore(embeddings=embeddings, config=config)


def ingest_pdfs(vector_store: RedisVectorStore) -> int:
    """
    Ingest all PDFs from DATA_DIR into Redis vector index.
    Returns # of chunks added.
    """
    pdfs = find_pdfs(DATA_DIR)
    if not pdfs:
        print(f"No PDFs found in {DATA_DIR}. Put PDF files there and re-run.")
        return 0

    raw_docs = load_pdf_docs(pdfs, base_dir=DATA_DIR)
    chunks = chunk_docs(raw_docs)

    texts = [c.page_content for c in chunks]
    metadatas = [c.metadata for c in chunks]

    vector_store.add_texts(texts=texts, metadatas=metadatas)
    return len(chunks)


def build_rag_chain(vector_store: RedisVectorStore):
    retriever = vector_store.as_retriever(search_kwargs={"k": TOP_K})

    prompt = ChatPromptTemplate.from_messages(
        [
            (
                "system",
                "You are a helpful assistant. Answer ONLY using the provided context. "
                "If the answer is not in the context, say you don't know. "
                "At the end, include a short 'Sources:' list of the PDFs/pages you used."
            ),
            ("human", "Question:\n{question}\n\nContext:\n{context}"),
        ]
    )

    llm = ChatOpenAI(model=CHAT_MODEL, temperature=0)

    # Main chain: question -> retrieve -> format context -> prompt -> LLM
    rag_chain = (
        {
            "question": RunnablePassthrough(),
            "context": retriever | RunnableLambda(format_docs_with_sources),
        }
        | prompt
        | llm
    )

    # Companion chain to fetch sources used for display
    def get_sources(q: str) -> Dict[str, Any]:
        docs = retriever.get_relevant_documents(q)
        return {"sources": extract_sources(docs)}

    sources_chain = RunnableLambda(get_sources)
    return rag_chain, sources_chain


def main():
    ensure_env()
    assert_redis_up(REDIS_URL)
    enable_langchain_cache(REDIS_URL, REDIS_CACHE_TTL_SECONDS)

    # Build FAISS index from PDFs
    vector_store = build_faiss_vector_store()

    # Build RAG
    rag_chain, sources_chain = build_rag_chain(vector_store)

    # Load evaluation CSV
    if not os.path.exists(EVAL_CSV_PATH):
        raise FileNotFoundError(f"CSV not found: {EVAL_CSV_PATH}")

    df = pd.read_csv(EVAL_CSV_PATH)

    if EVAL_QUESTION_COL not in df.columns or EVAL_REFERENCE_COL not in df.columns:
        raise ValueError(
            f"CSV must contain columns '{EVAL_QUESTION_COL}' and '{EVAL_REFERENCE_COL}'. "
            f"Found: {list(df.columns)}"
        )

    if EVAL_MAX_ROWS and EVAL_MAX_ROWS > 0:
        df = df.head(EVAL_MAX_ROWS).copy()

    emb = OpenAIEmbeddings(model=EMBEDDING_MODEL)

    results = []
    sims = []
    lat1_list = []
    lat2_list = []

    print(f"Evaluating {len(df)} rows from {EVAL_CSV_PATH} ...")
    print("Measuring latency for 1st invoke (cold) and 2nd invoke (warm/cached).")

    for i, row in df.iterrows():
        question = safe_text(row[EVAL_QUESTION_COL])
        ref_answer = safe_text(row[EVAL_REFERENCE_COL])

        if not question:
            results.append(
                {
                    "row": int(i),
                    "question": question,
                    "reference_answer": ref_answer,
                    "rag_answer_1": "",
                    "rag_answer_2": "",
                    "cosine_similarity": np.nan,
                    "latency_ms_1": np.nan,
                    "latency_ms_2": np.nan,
                    "sources": "",
                    "error": "empty_question",
                }
            )
            continue

        try:
            # Retrieve sources once (retriever.invoke inside sources_chain)
            srcs = sources_chain.invoke(question).get("sources", [])
            srcs_str = "; ".join(srcs) if isinstance(srcs, list) else safe_text(srcs)

            # --- First invoke (cold) ---
            t0 = time.perf_counter()
            ans1_msg = rag_chain.invoke(question)
            t1 = time.perf_counter()
            latency_ms_1 = (t1 - t0) * 1000.0

            rag_answer_1 = safe_text(getattr(ans1_msg, "content", str(ans1_msg)))

            # --- Second invoke (warm / ideally cached LLM response) ---
            t2 = time.perf_counter()
            ans2_msg = rag_chain.invoke(question)
            t3 = time.perf_counter()
            latency_ms_2 = (t3 - t2) * 1000.0

            rag_answer_2 = safe_text(getattr(ans2_msg, "content", str(ans2_msg)))

            # Cosine similarity: reference vs first answer (change to rag_answer_2 if desired)
            if ref_answer and rag_answer_1:
                ref_vec = emb.embed_query(ref_answer)
                rag_vec = emb.embed_query(rag_answer_1)
                sim = cosine_sim(ref_vec, rag_vec)
            else:
                sim = np.nan

            if not np.isnan(sim):
                sims.append(sim)
            if not np.isnan(latency_ms_1):
                lat1_list.append(latency_ms_1)
            if not np.isnan(latency_ms_2):
                lat2_list.append(latency_ms_2)

            results.append(
                {
                    "row": int(i),
                    "question": question,
                    "reference_answer": ref_answer,
                    "rag_answer_1": rag_answer_1,
                    "rag_answer_2": rag_answer_2,
                    "cosine_similarity": sim,
                    "latency_ms_1": latency_ms_1,
                    "latency_ms_2": latency_ms_2,
                    "sources": srcs_str,
                    "error": "",
                }
            )

            if (len(results) % 10) == 0:
                avg_sim = float(np.mean(sims)) if sims else float("nan")
                p50_1 = float(np.median(lat1_list)) if lat1_list else float("nan")
                p50_2 = float(np.median(lat2_list)) if lat2_list else float("nan")
                print(
                    f"Processed {len(results)}/{len(df)} | "
                    f"avg cosine: {avg_sim:.4f} | "
                    f"p50 latency1: {p50_1:.1f} ms | p50 latency2: {p50_2:.1f} ms"
                )

        except Exception as e:
            results.append(
                {
                    "row": int(i),
                    "question": question,
                    "reference_answer": ref_answer,
                    "rag_answer_1": "",
                    "rag_answer_2": "",
                    "cosine_similarity": np.nan,
                    "latency_ms_1": np.nan,
                    "latency_ms_2": np.nan,
                    "sources": "",
                    "error": repr(e),
                }
            )

    out_df = pd.DataFrame(results)
    out_df.to_csv(EVAL_OUT_CSV_PATH, index=False)

    valid_sim = out_df["cosine_similarity"].dropna()
    valid_lat1 = out_df["latency_ms_1"].dropna()
    valid_lat2 = out_df["latency_ms_2"].dropna()

    print("\n=== Evaluation Summary ===")
    print(f"Rows processed: {len(out_df)}")

    if len(valid_sim) > 0:
        print(f"Mean cosine similarity: {float(valid_sim.mean()):.4f}")
        print(f"Median cosine similarity: {float(valid_sim.median()):.4f}")
    else:
        print("Cosine similarity: n/a")

    if len(valid_lat1) > 0:
        print(f"Latency1 (ms) mean: {float(valid_lat1.mean()):.1f} | p50: {float(valid_lat1.median()):.1f}")
    else:
        print("Latency1: n/a")

    if len(valid_lat2) > 0:
        print(f"Latency2 (ms) mean: {float(valid_lat2.mean()):.1f} | p50: {float(valid_lat2.median()):.1f}")
    else:
        print("Latency2: n/a")

    print(f"Saved results to: {EVAL_OUT_CSV_PATH}")


#if __name__ == "__main__":
#    main()
main()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 385
#     380     print(f"Saved results to: {EVAL_OUT_CSV_PATH}")
#     383 #if __name__ == "__main__":
#     384 #    main()
# --> 385 main()
#
# Cell In[5], line 222, in main()
#     220 def main():
#     221     ensure_env()
# --> 222     assert_redis_up(REDIS_URL)
#     223     enable_langchain_cache(REDIS_URL, REDIS_CACHE_TTL_SECONDS)
#     225     # Build FAISS index from PDFs
#
# NameError: name 'assert_redis_up' is not defined

# %%
# !pip show langchain
# Out:
# Name: langchain
# Version: 1.0.3
# Summary: Building applications with LLMs through composability
# Home-page: https://docs.langchain.com/
# Author:
# Author-email:
# License: MIT
# Location: C:\Users\surya.adatravu\AppData\Local\anaconda3\envs\r1\Lib\site-packages
# Requires: langchain-core, langgraph, pydantic
# Required-by:

# %%
# !pip install -U langchain-redis redis
# Out:
# Collecting langchain-redis
#   Downloading langchain_redis-0.2.5-py3-none-any.whl.metadata (11 kB)
# Collecting redis
#   Downloading redis-7.1.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: anyio<5.0.0,>=4.9.0 in c:\users\surya.adatravu\appdata\local\anaconda3\envs\r1\lib\site-packages (from langchain-redis) (4.10.0)
# Requirement already satisfied: certifi<2026.0.0,>=2025.4.26 in c:\users\surya.adatravu\appdata\local\anaconda3\envs\r1\lib\site-packages (from langchain-redis) (2025.10.5)
# Requirement already satisfied: hf-xet<1.2.1 in c:\users\surya.adatravu\appdata\local\anaconda3\envs\r1\lib\site-packages (from langchain-redis) (1.2.0)
# Requirement already satisfied: httpcore<2.0.0,>=1.0.9 in c:\users\surya.adatravu\appdata\local\anaconda3\envs\r1\lib\site-packages (from langchain-redis) (1.0.9)
# Requirement already satisfied: jinja2<4.0.0,>=3.1.6 in c:\users\surya.adatravu\appdata\local\anaconda3\envs\r1\lib\site-packages (from langchain-redis) (3.1.6)
# Collecting langchain-core>=1.0.7 (from langchain-redis)
#   Downloading langchain_core-1.2.6-py3-none-any.whl.metadata (3.7 kB)
# Collecting python-ulid>=3.0.0 (from langchain-redis)
#   Downloading python_ulid-3.1.0-py3-none-any.whl.metadata (5.8 kB)
# Collecting redisvl<1.0.0,>=0.12.0 (from langchain-redis)
#   Downloading redisvl-0.13.2-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.13.2 in c:\users\surya.adatravu\appdata\local\anaconda3\envs\r1\lib\site-packages (from langchain-redis) (4.15.0)
# Collecting urllib3<3.0.0,>=2.4.0 (from langchain-redis)
#   Downloading urllib3-2.6.2-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: idna>=2.8 in c:\users\surya.adatravu\appdata\local\anaconda3\envs\r1\lib\site-packages (from anyio<5.0.0,>=4.9.0->langchain-redis) (3.7)
# Requirement already satisfied: sniffio>=1.1 in c:\users\surya.adatravu\appdata\local\anaconda3\envs\r1\lib\site-packages (from anyio<5.0.0,>=4.9.0->langchain-redis) (1.3.0)
# Requirement already satisfied: h11>=0.16 in c:\users\surya.adatravu\appdata\local\anaconda3\envs\r1\lib\site-packages (from httpcore<2.0.0,>=1.0.9->langchain-redis) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\surya.adatravu\appdata\local\anaconda3\envs\r1\lib\site-packages (from jinja2<4.0.0,>=3.1.6->langchain-redis) (3.0.2)
# Collecting jsonpath-ng>=1.5.0 (from redisvl<1.0.0,>=0.12.0->langchain-redis)
#   Downloading jsonpath_ng-1.7.0-py3-none-any.whl.metadata (18 kB)
# Collecting ml-dtypes<1.0.0,>=0.4.0 (from redisvl<1.0.0,>=0.12.0->langchain-redis)
#   Downloading ml_dtypes-0.5.4-cp313-cp313-win_amd64.whl.metadata (9.2 kB)
# Requirement already satisfied: numpy<3,>=1.26.0 in c:\users\surya.adatravu\appdata\local\anaconda3\envs\r1\lib\site-packages (from redisvl<1.0.0,>=0.12.0->langchain-redis) (2.3.4)
# Requirement already satisfied: pydantic<3,>=2 in c:\users\surya.adatravu\appdata\local\anaconda3\envs\r1\lib\site-packages (from redisvl<1.0.0,>=0.12.0->langchain-redis) (2.12.3)
# Requirement already satisfied: pyyaml<7.0,>=5.4 in c:\users\surya.adatravu\appdata\local\anaconda3\envs\r1\lib\site-packages (from redisvl<1.0.0,>=0.12.0->langchain-redis) (6.0.2)
# Requirement already satisfied: tenacity>=8.2.2 in c:\users\surya.adatravu\appdata\local\anaconda3\envs\r1\lib\site-packages (from redisvl<1.0.0,>=0.12.0->langchain-redis) (9.1.2)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\surya.adatravu\appdata\local\anaconda3\envs\r1\lib\site-packages (from pydantic<3,>=2->redisvl<1.0.0,>=0.12.0->langchain-redis) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in c:\users\surya.adatravu\appdata\local\anaconda3\envs\r1\lib\site-packages (from pydantic<3,>=2->redisvl<1.0.0,>=0.12.0->langchain-redis) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\surya.adatravu\appdata\local\anaconda3\envs\r1\lib\site-packages (from pydantic<3,>=2->redisvl<1.0.0,>=0.12.0->langchain-redis) (0.4.2)
# Collecting ply (from jsonpath-ng>=1.5.0->redisvl<1.0.0,>=0.12.0->langchain-redis)
#   Downloading ply-3.11-py2.py3-none-any.whl.metadata (844 bytes)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\surya.adatravu\appdata\local\anaconda3\envs\r1\lib\site-packages (from langchain-core>=1.0.7->langchain-redis) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\surya.adatravu\appdata\local\anaconda3\envs\r1\lib\site-packages (from langchain-core>=1.0.7->langchain-redis) (0.4.38)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\users\surya.adatravu\appdata\local\anaconda3\envs\r1\lib\site-packages (from langchain-core>=1.0.7->langchain-redis) (25.0)
# Collecting uuid-utils<1.0,>=0.12.0 (from langchain-core>=1.0.7->langchain-redis)
#   Downloading uuid_utils-0.12.0-cp39-abi3-win_amd64.whl.metadata (1.1 kB)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\surya.adatravu\appdata\local\anaconda3\envs\r1\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core>=1.0.7->langchain-redis) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\surya.adatravu\appdata\local\anaconda3\envs\r1\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core>=1.0.7->langchain-redis) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\surya.adatravu\appdata\local\anaconda3\envs\r1\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core>=1.0.7->langchain-redis) (3.11.4)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\surya.adatravu\appdata\local\anaconda3\envs\r1\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core>=1.0.7->langchain-redis) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\surya.adatravu\appdata\local\anaconda3\envs\r1\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core>=1.0.7->langchain-redis) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\surya.adatravu\appdata\local\anaconda3\envs\r1\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core>=1.0.7->langchain-redis) (0.25.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\surya.adatravu\appdata\local\anaconda3\envs\r1\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core>=1.0.7->langchain-redis) (3.4.4)
# Downloading langchain_redis-0.2.5-py3-none-any.whl (36 kB)
# Downloading redisvl-0.13.2-py3-none-any.whl (192 kB)
# Downloading redis-7.1.0-py3-none-any.whl (354 kB)
# Downloading ml_dtypes-0.5.4-cp313-cp313-win_amd64.whl (212 kB)
# Downloading urllib3-2.6.2-py3-none-any.whl (131 kB)
# Downloading jsonpath_ng-1.7.0-py3-none-any.whl (30 kB)
# Downloading langchain_core-1.2.6-py3-none-any.whl (489 kB)
# Downloading uuid_utils-0.12.0-cp39-abi3-win_amd64.whl (183 kB)
# Downloading python_ulid-3.1.0-py3-none-any.whl (11 kB)
# Downloading ply-3.11-py2.py3-none-any.whl (49 kB)
# Installing collected packages: ply, uuid-utils, urllib3, redis, python-ulid, ml-dtypes, jsonpath-ng, redisvl, langchain-core, langchain-redis
#
#    ----------------------------------------  0/10 [ply]
#   Attempting uninstall: urllib3
#    ----------------------------------------  0/10 [ply]
#     Found existing installation: urllib3 2.3.0
#    ----------------------------------------  0/10 [ply]
#     Uninstalling urllib3-2.3.0:
#    ----------------------------------------  0/10 [ply]
#       Successfully uninstalled urllib3-2.3.0
#    ----------------------------------------  0/10 [ply]
#    -------- -------------------------------  2/10 [urllib3]
#    -------- -------------------------------  2/10 [urllib3]
#    -------- -------------------------------  2/10 [urllib3]
#    -------- -------------------------------  2/10 [urllib3]
#    -------- -------------------------------  2/10 [urllib3]
#    ------------ ---------------------------  3/10 [redis]
#    ------------ ---------------------------  3/10 [redis]
#    ------------ ---------------------------  3/10 [redis]
#    ------------ ---------------------------  3/10 [redis]
#    ------------ ---------------------------  3/10 [redis]
#    ------------ ---------------------------  3/10 [redis]
#    ------------ ---------------------------  3/10 [redis]
#    ------------ ---------------------------  3/10 [redis]
#    ------------ ---------------------------  3/10 [redis]
#    ------------ ---------------------------  3/10 [redis]
#    ------------ ---------------------------  3/10 [redis]
#    ------------ ---------------------------  3/10 [redis]
#    ---------------- -----------------------  4/10 [python-ulid]
#    -------------------- -------------------  5/10 [ml-dtypes]
#    ------------------------ ---------------  6/10 [jsonpath-ng]
#    ---------------------------- -----------  7/10 [redisvl]
#    ---------------------------- -----------  7/10 [redisvl]
#    ---------------------------- -----------  7/10 [redisvl]
#    ---------------------------- -----------  7/10 [redisvl]
#    ---------------------------- -----------  7/10 [redisvl]
#    ---------------------------- -----------  7/10 [redisvl]
#    ---------------------------- -----------  7/10 [redisvl]
#    ---------------------------- -----------  7/10 [redisvl]
#    ---------------------------- -----------  7/10 [redisvl]
#    ---------------------------- -----------  7/10 [redisvl]
#    ---------------------------- -----------  7/10 [redisvl]
#   Attempting uninstall: langchain-core
#    ---------------------------- -----------  7/10 [redisvl]
#     Found existing installation: langchain-core 1.0.2
#    ---------------------------- -----------  7/10 [redisvl]
#     Uninstalling langchain-core-1.0.2:
#    ---------------------------- -----------  7/10 [redisvl]
#       Successfully uninstalled langchain-core-1.0.2
#    ---------------------------- -----------  7/10 [redisvl]
#    -------------------------------- -------  8/10 [langchain-core]
#    -------------------------------- -------  8/10 [langchain-core]
#    -------------------------------- -------  8/10 [langchain-core]
#    -------------------------------- -------  8/10 [langchain-core]
#    -------------------------------- -------  8/10 [langchain-core]
#    -------------------------------- -------  8/10 [langchain-core]
#    -------------------------------- -------  8/10 [langchain-core]
#    -------------------------------- -------  8/10 [langchain-core]
#    -------------------------------- -------  8/10 [langchain-core]
#    -------------------------------- -------  8/10 [langchain-core]
#    -------------------------------- -------  8/10 [langchain-core]
#    -------------------------------- -------  8/10 [langchain-core]
#    -------------------------------- -------  8/10 [langchain-core]
#    -------------------------------- -------  8/10 [langchain-core]
#    -------------------------------- -------  8/10 [langchain-core]
#    -------------------------------- -------  8/10 [langchain-core]
#    -------------------------------- -------  8/10 [langchain-core]
#    -------------------------------- -------  8/10 [langchain-core]
#    -------------------------------- -------  8/10 [langchain-core]
#    -------------------------------- -------  8/10 [langchain-core]
#    -------------------------------- -------  8/10 [langchain-core]
#    ------------------------------------ ---  9/10 [langchain-redis]
#    ---------------------------------------- 10/10 [langchain-redis]
#
# Successfully installed jsonpath-ng-1.7.0 langchain-core-1.2.6 langchain-redis-0.2.5 ml-dtypes-0.5.4 ply-3.11 python-ulid-3.1.0 redis-7.1.0 redisvl-0.13.2 urllib3-2.6.2 uuid-utils-0.12.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# kubernetes 34.1.0 requires urllib3<2.4.0,>=1.24.2, but you have urllib3 2.6.2 which is incompatible.
